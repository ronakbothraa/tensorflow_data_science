# %%
import pandas as pd
import os

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
surveys = os.listdir('./data')

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
pd.set_option('display.max_column', 85)

# %%
schema_df = pd.read_csv(f"data/{surveys[2]}")

# %%
schema_df.tail(10)
# Out:
#        qid        qname                                           question  \
# 68  QID289  Knowledge_2  Knowledge silos prevent me from getting ideas ...
# 69  QID289  Knowledge_3  I can find up-to-date information within my or...
# 70  QID289  Knowledge_4  I am able to quickly find answers to my questi...
# 71  QID289  Knowledge_5  I know which system or resource to use to find...
# 72  QID289  Knowledge_6  I often find myself answering questions that I...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp type selector
# 68        NaN   MC     MAVR
# 69        NaN   MC     MAVR
# 70        NaN   MC     MAVR
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
df[df.columns[4]].value_counts() # employment status info
# Out:
# Employment
# Employed, full-time                                                                                                                                                                                             53748
# Student, full-time                                                                                                                                                                                               7430
# Independent contractor, freelancer, or self-employed                                                                                                                                                             7076
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                                                                                         4354
# ...

# %%
df.loc[0:4, df.columns[4:8]]
# Out:
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# 4                                Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
# 3                                              Hobby
# 4  Hobby;Contribute to open-source projects;Profe...
#
#                                         EdLevel
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.set_index('ResponseId', inplace=True)

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
schema_df.columns
# Out:
# Index(['qid', 'qname', 'question', 'force_resp', 'type', 'selector'], dtype='object')

# %%
schema_df.head()
# Out:
#       qid     qname                                           question  \
# 0   QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12  MetaInfo                                  Browser Meta Info
# 2  QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# 3  QID312      Q120
# 4    QID1        S1  <span style="font-size:22px; font-family: aria...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    DB       TB

# %%
del schema_df['question'][0]

# %%
schema_df['question']
# Out:
# 1                                     Browser Meta Info
# 2     <div><span style="font-size:19px;"><strong>You...
# 3
# 4     <span style="font-size:22px; font-family: aria...
# 5     Which of the following options best describes ...
# 6                                   What is your age? *
# 7     Which of the following best describes your cur...
# 8     Which best describes your current work situation?
# 9     Which of the following best describes the code...
# 10    <span style="font-size:22px; font-family: aria...
# 11    Which of the following best describes the high...
# 12     How do you learn to code? Select all that apply.
# 13    What online resources do you use to learn to c...
# 14    What online courses or certifications do you u...
# 15    Including any education, how many years have y...
# 16    NOT including education, how many years have y...
# 17    Which of the following describes your current ...
# 18    Approximately how many people are employed by ...
# ...

# %%
df.set_index('ResponseId', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14692\2397813185.py in ?()
# ----> 1 df.set_index('ResponseId', inplace=True)
#
# ~\anaconda3\envs\first\lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['ResponseId'] are in the columns"

# %%
schema_df.reset_index(inplace=True)

# %%
schema_df.head()
# Out:
#    index     qid     qname                                           question  \
# 0      0   QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# 1      1   QID12  MetaInfo                                  Browser Meta Info
# 2      2  QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# 3      3  QID312      Q120
# 4      4    QID1        S1  <span style="font-size:22px; font-family: aria...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    DB       TB

# %%
df.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %%
filt = (df['ConvertedCompYearly'] > 80000)
filt2 = (df['Country'].isin(['United States of America']))
filt3 = (df['LanguageHaveWorkedWith'].str.contains('Python', na=False))
total_filt = filt&filt3&filt2

# %%
df.loc[total_filt, ['LanguageHaveWorkedWith', 'Country', 'ConvertedCompYearly']]
# Out:
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 2                                  HTML/CSS;JavaScript;Python
# 14                                          C;C++;Python;Rust
# 111                     HTML/CSS;JavaScript;Python;TypeScript
# 122             Go;HTML/CSS;JavaScript;PowerShell;Python;Rust
# 138                                              Python;R;SQL
# ...                                                       ...
# 89087       Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 89113           C#;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 89114       Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 89140           Bash/Shell (all shells);C++;JavaScript;Python
# 89141                                   JavaScript;Python;SQL
#
#                              Country  ConvertedCompYearly
# ResponseId
# 2           United States of America             285000.0
# 14          United States of America             150000.0
# ...

# %%
df.rename(columns={'LanguageHaveWorkedWith':'LanguageWorkedWith'}, inplace=True )

# %%
df.loc[total_filt, ['LanguageWorkedWith', 'Country', 'ConvertedCompYearly']]
# Out:
#                                            LanguageWorkedWith  \
# ResponseId
# 2                                  HTML/CSS;JavaScript;Python
# 14                                          C;C++;Python;Rust
# 111                     HTML/CSS;JavaScript;Python;TypeScript
# 122             Go;HTML/CSS;JavaScript;PowerShell;Python;Rust
# 138                                              Python;R;SQL
# ...                                                       ...
# 89087       Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 89113           C#;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 89114       Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 89140           Bash/Shell (all shells);C++;JavaScript;Python
# 89141                                   JavaScript;Python;SQL
#
#                              Country  ConvertedCompYearly
# ResponseId
# 2           United States of America             285000.0
# 14          United States of America             150000.0
# ...
